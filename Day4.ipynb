# %%
type(4)
# Out:
# int

# %%
int(4.5)
# Out:
# 4

# %%
float(4)
# Out:
# 4.0

# %%
str(4)
# Out:
# '4'

# %%
max(1, 2, 3)
# Out:
# 3

# %%
min(1, 2, 3)
# Out:
# 1

# %%
z=-20
abs(z)
# Out:
# 20

# %%
a=[1, 2, 3]
sum(a)
# Out:
# 6

# %%
round(3.14159, 2)
# Out:
# 3.14

# %%
round(3.14159)
# Out:
# 3

# %%
2**10
# Out:
# 1024

# %%
len("Hello, World!")
# Out:
# 13
