# %% [markdown]
# ## Variables

# %%
x = 5

# %%
x
# Out:
# 5

# %%
y = 8

# %%
y
# Out:
# 8

# %%
print (y)
# Out:
# 8

# %%
x,y = (1,2)

# %%
x
# Out:
# 1

# %%
y
# Out:
# 2

# %%
x,y,z = (1,2,3)

# %% [markdown]
# ## Numbers and Boolean Values

# %%
x1 = 5

# %%
type(x1)
# Out:
# int

# %%
type(-6)
# Out:
# int

# %%
x2 = 4.75

# %%
type(x2)
# Out:
# float

# %%
int(x2)
# Out:
# 4

# %%
float(5)
# Out:
# 5.0

# %%
x3 = True

# %%
type(x3)
# Out:
# bool

# %%
x3 = True

# %% [markdown]
# ## Strings

# %%
'George'
# Out:
# 'George'

# %%
'George'
# Out:
# 'George'

# %%
"George"
# Out:
# 'George'

# %%
print ('George')
# Out:
# George

# %%
print ("George")
# Out:
# George

# %%
x4 = "George"

# %%
x4
# Out:
# 'George'

# %%
y = 10
print ('y' + "Dollars")
# Out:
# yDollars

# %%
y = 10
print (str(y) + " Dollars")
# Out:
# 10 Dollars

# %%
'Im fine'
# Out:
# 'Im fine'

# %%
"I'm fine"
# Out:
# "I'm fine"

# %%
'I\'m fine'
# Out:
# "I'm fine"

# %%
'Press "Enter"'
# Out:
# 'Press "Enter"'

# %%
'Red' 'car'
# Out:
# 'Redcar'

# %%
'Red ' 'car'
# Out:
# 'Red car'

# %%
'Red ' + 'car'
# Out:
# 'Red car'

# %%
print ('Red ' + 'car')
# Out:
# Red car

# %%
print ('Red', 'car')
# Out:
# Red car
